# %% [markdown]
# <a href="https://colab.research.google.com/github/ablatnick/MIS2800/blob/main/ic3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade pandas ipython-sql prettytable==3.10.1

# %%
# !pip install ipython-sql
print("ipython sql installed")
# Out:
# ...
# ipython sql installed

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
conn = sqlite3.connect('SuperBowl_Finance.db')
print("SuperBowl_Finance database created")
# Out:
# SuperBowl_Finance database created

# %%
# %sql sqlite:///SuperBowl_Finance.db

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS Ad_Buys (
#     ticker TEXT PRIMARY KEY,
#     company_name TEXT,
#     ad_cost_millions REAL,
#     airtime_seconds INTEGER
# ) STRICT;
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# []

# %%
# %%sql
# INSERT INTO stock_performance (ticker, price_before_game, price_week_after_game, trading_volume_millions)
# VALUES
#   ('PEP', 168.50, 172.10, 45),
#   ('GOOGL', 142.80, 145.20, 110),
#   ('AMZN', 170.20, 178.45, 95),
#   ('VZ', 40.10, 39.85, 60),
#   ('TSLA', 190.00, 185.20, 150),
#   ('TMUS', 197.68, 199.34, 100),
#   ('STLA', 22.40, 23.10, 15);
# Out:
#  * sqlite:///SuperBowl_Finance.db
# 7 rows affected.
# []

# %%
# Instructions: Create a table named Ad_Buys with columns for ticker, company_name, ad_cost_millions, airtime_second
# The ticker should be a TEXT data type and serve as the Primary Key.
# Select an appropriate data_type for the other columns.
# Remember to use the STRICT keyword to ensure the datatype is enforced.
# %%sql
CREATE Ad_Buys (
    ticker TEXT PRIMARY KEY,
    company_name TEXT,
    ad_cost_millions REAL,
     airtime_seconds INTEGER
) STRICT;
# Out:
#  * sqlite:///SuperBowl_Finance.db
# (sqlite3.OperationalError) near "Ad_Buys": syntax error
# [SQL: CREATE Ad_Buys (
#     ticker TEXT PRIMARY KEY,
#     company_name TEXT,
#     ad_cost_millions REAL,
#      airtime_seconds INTEGER
# ) STRICT;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %%sql
# INSERT INTO ad_buys (ticker, company_name, ad_cost_millions, airtime_seconds)
# VALUES
#   ('PEP', 'PepsiCo', 7.0, 30),
#   ('GOOGL', 'Alphabet (Google)', 14.0, 60),
#   ('AMZN', 'Amazon', 14.0, 60),
#   ('VZ', 'Verizon', 7.0, 30),
#   ('TSLA', 'Tesla', 0.0, 0), -- Tesla doesn't buy ads
#   ('TMUS', 'Tmobile', 10.0, 30),
#   ('STLA', 'Stellantis (Jeep)', 6.5, 30);
# Out:
#  * sqlite:///SuperBowl_Finance.db
# (sqlite3.IntegrityError) UNIQUE constraint failed: ad_buys.ticker
# [SQL: INSERT INTO ad_buys (ticker, company_name, ad_cost_millions, airtime_seconds)
# VALUES
#   ('PEP', 'PepsiCo', 7.0, 30),
#   ('GOOGL', 'Alphabet (Google)', 14.0, 60),
#   ('AMZN', 'Amazon', 14.0, 60),
#   ('VZ', 'Verizon', 7.0, 30),
#   ('TSLA', 'Tesla', 0.0, 0), -- Tesla doesn't buy ads
#   ('TMUS', 'Tmobile', 10.0, 30),
#   ('STLA', 'Stellantis (Jeep)', 6.5, 30);]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
# Instructions: Show all the columns from the stock_performance table
# %%sql
SELECT * From stock_performance;
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# [('PEP', 168.5, 172.1, 45),
#  ('GOOGL', 142.8, 145.2, 110),
#  ('AMZN', 170.2, 178.45, 95),
#  ('VZ', 40.1, 39.85, 60),
#  ('TSLA', 190.0, 185.2, 150),
#  ('TMUS', 197.68, 199.34, 100),
#  ('STLA', 22.4, 23.1, 15),
#  ('PEP', 168.5, 172.1, 45),
#  ('GOOGL', 142.8, 145.2, 110),
#  ('AMZN', 170.2, 178.45, 95),
#  ('VZ', 40.1, 39.85, 60),
#  ('TSLA', 190.0, 185.2, 150),
#  ('TMUS', 197.68, 199.34, 100),
#  ('STLA', 22.4, 23.1, 15),
#  ('PEP', 168.5, 172.1, 45),
#  ('GOOGL', 142.8, 145.2, 110),
#  ('AMZN', 170.2, 178.45, 95),
#  ('VZ', 40.1, 39.85, 60),
#  ('TSLA', 190.0, 185.2, 150),
#  ('TMUS', 197.68, 199.34, 100),
#  ('STLA', 22.4, 23.1, 15)]

# %%
# %%sql
# SELECT ticker, price_before_game FROM stock_performance ORDER BY ticker ASC
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# [('AMZN', 170.2),
#  ('AMZN', 170.2),
#  ('AMZN', 170.2),
#  ('GOOGL', 142.8),
#  ('GOOGL', 142.8),
#  ('GOOGL', 142.8),
#  ('PEP', 168.5),
#  ('PEP', 168.5),
#  ('PEP', 168.5),
#  ('STLA', 22.4),
#  ('STLA', 22.4),
#  ('STLA', 22.4),
#  ('TMUS', 197.68),
#  ('TMUS', 197.68),
#  ('TMUS', 197.68),
#  ('TSLA', 190.0),
#  ('TSLA', 190.0),
#  ('TSLA', 190.0),
#  ('VZ', 40.1),
#  ('VZ', 40.1),
#  ('VZ', 40.1)]

# %%
# %%sql
# SELECT * FROM stock_performance WHERE ticker LIKE 'T%'
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# [('TSLA', 190.0, 185.2, 150),
#  ('TMUS', 197.68, 199.34, 100),
#  ('TSLA', 190.0, 185.2, 150),
#  ('TMUS', 197.68, 199.34, 100),
#  ('TSLA', 190.0, 185.2, 150),
#  ('TMUS', 197.68, 199.34, 100)]

# %%
# %%sql
# SELECT ticker, price_week_after_game FROM stock_performance WHERE price_week_after_game > 150
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# [('PEP', 172.1),
#  ('AMZN', 178.45),
#  ('TSLA', 185.2),
#  ('TMUS', 199.34),
#  ('PEP', 172.1),
#  ('AMZN', 178.45),
#  ('TSLA', 185.2),
#  ('TMUS', 199.34),
#  ('PEP', 172.1),
#  ('AMZN', 178.45),
#  ('TSLA', 185.2),
#  ('TMUS', 199.34)]

# %%
# %%sql
# SELECT * FROM ad_buys
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# [('PEP', 'PepsiCo', 7.0, 30),
#  ('GOOGL', 'Alphabet\xa0(Google)', 14.0, 60),
#  ('AMZN', 'Amazon', 14.0, 60),
#  ('VZ', 'Verizon', 7.0, 30),
#  ('TSLA', 'Tesla', 0.0, 0),
#  ('TMUS', 'Tmobile', 10.0, 30),
#  ('STLA', 'Stellantis\xa0(Jeep)', 6.5, 30)]

# %%
# %%sql
# SELECT ticker, company_name FROM ad_buys ORDER BY company_name DESC;
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# [('VZ', 'Verizon'),
#  ('TMUS', 'Tmobile'),
#  ('TSLA', 'Tesla'),
#  ('STLA', 'Stellantis\xa0(Jeep)'),
#  ('PEP', 'PepsiCo'),
#  ('AMZN', 'Amazon'),
#  ('GOOGL', 'Alphabet\xa0(Google)')]

# %%
# %%sql
# SELECT ticker, airtime_seconds
# FROM ad_buys
# WHERE ticker LIKE 'T%'
#   AND airtime_seconds = 0;
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# [('TSLA', 0)]
